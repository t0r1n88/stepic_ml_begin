# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/StudentsPerformance.csv')

# %%
# Из пандас
df['math score'].hist()

# %%
# чтобы не писало техническую информацию нужно поставить ;
df['reading score'].hist();

# %%
# Использование matplotlib
df.plot.scatter(x='reading score',y='math score');

# %%
# Использование seaborn
sns.lmplot(x='reading score',y='math score',data=df);

# %%
# Группировка на графике
sns.lmplot(x='reading score',y='math score',hue='gender',data=df);

# %%
df.head(1)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74

# %%
sns.lmplot(x='reading score',y='math score',hue='parental level of education',data=df);

# %%
# Кастомизация графика seaborn
# Сохраняем график в объект
ax = sns.lmplot(x='reading score',y='math score',hue='gender',data=df);
ax.set_xlabels('Математика')
ax.set_ylabels('Чтение')

# %%
# Убрать линию регрессии
sns.lmplot(x='reading score',y='math score',hue='gender',fit_reg=False,data=df);

# %%
# 1.7.4
df = pd.read_csv('..\data\income.csv')

# %%
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
# Линия
df.plot();

# %%
sns.lineplot(x=df.index,y=df['income'])

# %%
sns.lineplot(data=df)

# %%
df['income'].plot()

# %%
plt.plot(df.index,df['income'])

# %%
df['income'].plot()

# %%
df.plot(kind='line')

# %%
# 1.7.8
df = pd.read_csv('..\data\dataset_209770_6.txt',sep=' ')

# %%
# Чтобы не считывать заголовки используем аргумент header
df = pd.read_csv('..\data\dataset_209770_6.txt',sep=' ',header=None)

# %%
df.head()
# Out:
#                     0                   1
# 0                   x                   y
# 1   509.2226378554073   1208.132359364461
# 2  504.15697178768517  1211.1695437826893
# 3   495.9356844621546    1213.29966064855
# 4   908.3235627176356   301.8149866471877

# %%
df.plot.scatter(x='x',y='y')

# %% [markdown]
# Почему не сказали об этом божественно-удобном методе? ---> data=pd.read_clipboard()
#
# Данный метод автоматом пропускает скопированный в буффер текст через pd.read_csv и подбирает автоматом параметры. Нет нужны скачивать малые файлы на машину, когда можно просто ctrl+c ---> data=pd.read_clipboard().
#
# Очень удобно.

# %%
# 1.7.6 Тепловая карта
df = pd.read_csv('..\data\genome_matrix.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
# Вот так не работает потому что тепловая карта это график зависимостей, а здесь у нас индекс в виде 
# последовательности от нуля. Необходимо сделать так чтобы первая колонка стала индексом.

sns.heatmap(df,cmap='viridis')

# %%
# Это можно сделать указав что  индексом  при считываении файла будет нулевой столбец 
df = pd.read_csv('..\data\genome_matrix.csv',index_col=0)

# %%
df.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g=sns.heatmap(df,cmap='viridis');
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
sns.heatmap()

# %%
# 1.7.7

# %%
df = pd.read_csv('../data/dota_hero_stats.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0 attack_type  id  legs localized_name                    name  \
# 0           0       Melee   1     2      Anti-Mage  npc_dota_hero_antimage
#
#   primary_attr                         roles
# 0          agi  ['Carry', 'Escape', 'Nuker']

# %%
df['roles'].apply(lambda x:len(x.split(','))).value_counts().plot(kind='bar')

# %%
c = df['roles'].apply(lambda x:len(x.split(','))).value_counts()
c
# Out:
# 4    38
# 5    33
# 3    28
# 2     9
# 6     8
# 1     1
# Name: roles, dtype: int64

# %%
sns.barplot(x=c.index,y=c)

# %%
# 1.7.8
df = pd.read_csv('..\data\iris.csv',index_col = 0)

# %%
df.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
# 5           5.4          3.9           1.7          0.4        0
# 6           4.6          3.4           1.4          0.3        0
# 7           5.0          3.4           1.5          0.2        0
# 8           4.4          2.9           1.4          0.2        0
# 9           4.9          3.1           1.5          0.1        0

# %%
df.shape
# Out:
# (150, 6)

# %%
for column in df.columns:
    sns.distplot(df[column],label=column);
plt.legend()

# %%
# вариант с kdeplot
for i in df.columns:
    sns.kdeplot(df[i]);

# %% [markdown]
# В данном случае очевидно что kdeplot более читаемый вариант.

# %%
df['petal length']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal length, Length: 150, dtype: float64

# %%
# orient направление диаграммы
sns.violinplot(x=df['petal length'],orient='v');

# %%
# 1.7.10
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.pairplot(df);

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %% [markdown]
# Помним что чем ближе точки к прямой y=x тем больше корреляция.
